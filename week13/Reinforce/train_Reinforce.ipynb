# %%
import tensorflow as tf
import environment as Env
import keras
import numpy as np
import random

# %%
# 강화학습 인공신경망
class REINFORCE(tf.keras.Model):
    def __init__(self, action_size):
        super(REINFORCE, self).__init__()
        self.fc1 = keras.layers.Dense(24, activation = 'relu') # 은닉층 (unit 개수 : 30, 활성함수 : ReLU)
        self.fc2 = keras.layers.Dense(24, activation = 'relu') # 은닉층 (unit 개수 : 30, 활성함수 : ReLU)
        self.fc_out = keras.layers.Dense(action_size, activation = 'softmax') # 출력층 (action_size = 5, 상, 하, 좌, 우, 제자리)
        
        
    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        policy = self.fc_out(x)
        
        return policy

# %%
# 그리드월드 예제에서의 딥살사 에이전트
class REINFORCEAgent:
    def __init__(self, state_size, action_size):
        # 상태의 크기와 행동의 크기 정의
        self.state_size = state_size # 상태의 크기 정의
        self.action_size = action_size # 행동의 크기 정의
        
        # REINFORCE 하이퍼 파라메터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        
        self.model = REINFORCE(self.action_size)
        self.optimizer = keras.optimizers.Adam(lr = self.learning_rate)
        self.states, self.actions, self.rewards = [], [], [] # 상태, 행동, 보상을 저장하기 위해 list 형식으로 정의
        
    # 정책을 통해 행동 선택
    def get_action(self, state):
        policy = self.model(state)[0] # 현재 상태를 입력해 정책 확률만 출력
        policy = np.array(policy) # list를 numpy.array로 변환
        action = np.random.choice(self.action_size, 1, p = policy)[0] 
        #print("\n\nget action")
        #print("policy : ", policy)
        #print("action : ", action)
        return np.random.choice(self.action_size, 1, p = policy)[0] # 확률을 적용한 random.choice 함수로 0~4 중에 한 수치를 선택
    
    def discount_rewards(self, rewards): # 반환 값 계산 함수(입력 : 저장한 reward, 출력 : 반환값 array)
        discounted_rewards = np.zeros_like(rewards)
        running_add = 0
        for t in reversed(range(0, len(rewards))): # 효율적으로 반환값을 계산하기 위해 거꾸로 진행
            running_add = running_add * self.discount_factor + rewards[t] # 반환값 = reward(t번째) + discount factor * 반환값
            discounted_rewards[t] = running_add # 반환값을 discounted_rewards라는 array에서 저장
        return discounted_rewards
    
    def append_sample(self, state, action, reward): # 한 에피소드 동안의 상태, 행동, 보상을 저장
        self.states.append(state[0]) # 상태 저장
        self.rewards.append(reward) # 보상 저장
        act = np.zeros(self.action_size) # 행동을 one hot encoding으로 변환
        act[action] = 1
        self.actions.append(act) # 행동을 저장
        
    def train_model(self): # 정책신경망 업데이트 함수        
        discounted_rewards = np.float32(self.discount_rewards(self.rewards)) # 보상을 discount_rewards 함수를 통해 반환값을 return하고 반환값을 numpy.float32형식으로 변환
        discounted_rewards -= np.mean(discounted_rewards) # 데이터를 Z-score 표준화 방법으로 정규화함(정책 신경망의 업데이트 성능 향상)
        discounted_rewards /= np.std(discounted_rewards)
        
        # 크로스 엔트로피 오류함수 계산
        model_params = self.model.trainable_variables
        
        with tf.GradientTape() as tape:
            tape.watch(model_params)
            policies = self.model(np.array(self.states))
            actions = np.array(self.actions)
            action_prob = tf.reduce_sum(actions * policies, axis = 1)
            cross_entropy = -tf.math.log(action_prob + 1e-5)
            loss = tf.reduce_sum(cross_entropy * discounted_rewards)
            entropy = -policies * tf.math.log(policies)
        
        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        self.states, self.actions, self.rewards = [], [], [] # 상태, 행동, 보상 list 초기화
        return np.mean(entropy)

# %%
if __name__ == "__main__":
    # 환경과 에이전트 생성
    env = Env.Env(render_speed = 0.01) # 환경 instance 생성 (게임 속도를 0.01로 조정)
    state_size = 15 # 상태 개수 정의
    action_space = [0, 1, 2, 3, 4] # 행동 정의
    action_size = len(action_space) # 행동 개수 정의
    agent = REINFORCEAgent(state_size, action_size) # REINFORCE instance 생성
    
    scores, episodes = [], []
    
    EPISODES = 1000 # episode 횟수 정의.
    
    for e in range(EPISODES): 
        done = False
        score = 0
        step = 0
        
        # env 초기화
        state = env.reset() # 환경을 초기화하고 상태를 받음 (list 형식)
        state = np.reshape(state, [1, state_size]) # 상태 list를 (1, 15)의 numpy.array로 변환
        
        while not done: # episode가 끝나지 않으면 계속 실행
            # 몇 번째 스텝인지 확인
            step += 1
            
            # 현재 상태에 대한 행동 선택
            action = agent.get_action(state)
            
            # 선택한 행동으로 환경에서 한 타임스텝 진행 후 샘플 수집
            next_state, reward, done = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            
            # 샘플로 모델 학습
            agent.append_sample(state, action, reward)
            score += reward
            state = next_state
            
            if done: # episode가 끝나면(goal에 도착하면)
                print("step : {:d}".format(step))
                
                # 에피소드마다 정책신경망 업데이트
                entropy = agent.train_model()
                
                # 에피소드마다 학습결과 출력
                print("episode: {:3d} | score: {:3d} | entropy: {:.3f}\n".format(e, score, entropy))                
                #agent.__init__.self.model = tf.zeros(shape=None, name=None)
                
                
        # 10 에피소드마다 모델 저장
        if e % 10 == 0:
            agent.model.save_weights('save_model/model', save_format='tf')
# Out:
# step : 259
# episode:   0 | score: -33 | entropy: 0.294
#
# step : 202
# episode:   1 | score: -18 | entropy: 0.298
#
# step : 251
# episode:   2 | score: -20 | entropy: 0.298
#
# step : 241
# episode:   3 | score: -24 | entropy: 0.300
#
# step : 146
# episode:   4 | score:  -8 | entropy: 0.290
#
# step : 24
# episode:   5 | score:   0 | entropy: 0.303
#
# step : 73
# episode:   6 | score:   0 | entropy: 0.293
#
# step : 58
# episode:   7 | score:  -1 | entropy: 0.297
#
# step : 231
# episode:   8 | score: -15 | entropy: 0.297
#
# step : 44
# episode:   9 | score:  -4 | entropy: 0.299
#
# step : 22
# episode:  10 | score:  -3 | entropy: 0.288
#
# step : 124
# episode:  11 | score:  -8 | entropy: 0.297
#
# step : 43
# episode:  12 | score:   0 | entropy: 0.297
#
# step : 91
# episode:  13 | score:  -2 | entropy: 0.294
#
# step : 49
# episode:  14 | score:  -3 | entropy: 0.297
#
# step : 104
# episode:  15 | score:  -6 | entropy: 0.294
#
# step : 33
# episode:  16 | score:   1 | entropy: 0.292
#
# step : 82
# episode:  17 | score:  -7 | entropy: 0.293
#
# step : 17
# episode:  18 | score:   1 | entropy: 0.290
#
# step : 126
# episode:  19 | score:  -6 | entropy: 0.297
#
# step : 28
# episode:  20 | score:  -4 | entropy: 0.295
#
# step : 37
# episode:  21 | score:  -2 | entropy: 0.287
#
# step : 67
# episode:  22 | score:  -7 | entropy: 0.298
#
# step : 57
# episode:  23 | score:  -8 | entropy: 0.298
#
# step : 95
# episode:  24 | score:  -7 | entropy: 0.290
#
# step : 113
# episode:  25 | score:  -6 | entropy: 0.291
#
# step : 98
# episode:  26 | score:  -7 | entropy: 0.290
#
# step : 38
# episode:  27 | score:  -4 | entropy: 0.291
#
# step : 76
# episode:  28 | score:   0 | entropy: 0.286
#
# step : 52
# episode:  29 | score:  -3 | entropy: 0.285
#
# step : 35
# episode:  30 | score:  -2 | entropy: 0.280
#
# step : 25
# episode:  31 | score:  -2 | entropy: 0.279
#
# step : 70
# episode:  32 | score:  -8 | entropy: 0.286
#
# step : 33
# episode:  33 | score:  -1 | entropy: 0.282
#
# step : 99
# episode:  34 | score:  -1 | entropy: 0.273
#
# step : 27
# episode:  35 | score:  -3 | entropy: 0.291
#
# step : 28
# episode:  36 | score:  -2 | entropy: 0.285
#
# step : 101
# episode:  37 | score: -15 | entropy: 0.286
#
# step : 21
# episode:  38 | score:   0 | entropy: 0.262
#
# step : 48
# episode:  39 | score:   1 | entropy: 0.272
#
# step : 137
# episode:  40 | score: -15 | entropy: 0.284
#
# step : 82
# episode:  41 | score:  -9 | entropy: 0.280
#
# step : 39
# episode:  42 | score:  -6 | entropy: 0.279
#
# step : 23
# episode:  43 | score:  -2 | entropy: 0.269
#
# step : 55
# episode:  44 | score:   1 | entropy: 0.271
#
# step : 19
# episode:  45 | score:   0 | entropy: 0.275
#
# step : 23
# episode:  46 | score:   0 | entropy: 0.273
#
# step : 70
# episode:  47 | score:  -8 | entropy: 0.282
#
# step : 61
# episode:  48 | score:  -2 | entropy: 0.275
#
# step : 24
# episode:  49 | score:   0 | entropy: 0.269
#
# step : 24
# episode:  50 | score:  -1 | entropy: 0.272
#
# step : 22
# episode:  51 | score:  -1 | entropy: 0.264
#
# step : 50
# episode:  52 | score:  -2 | entropy: 0.282
#
# step : 70
# episode:  53 | score:  -2 | entropy: 0.272
#
# step : 36
# episode:  54 | score:  -6 | entropy: 0.291
#
# step : 45
# episode:  55 | score:   0 | entropy: 0.272
#
# step : 50
# episode:  56 | score:   1 | entropy: 0.273
#
# step : 23
# episode:  57 | score:  -1 | entropy: 0.276
#
# step : 85
# episode:  58 | score:  -8 | entropy: 0.281
#
# step : 45
# episode:  59 | score:  -7 | entropy: 0.289
#
# step : 23
# episode:  60 | score:   0 | entropy: 0.276
#
# step : 88
# episode:  61 | score:  -2 | entropy: 0.279
#
# step : 51
# episode:  62 | score:  -3 | entropy: 0.283
#
# step : 17
# episode:  63 | score:   1 | entropy: 0.281
#
# step : 18
# episode:  64 | score:   1 | entropy: 0.273
#
# step : 38
# episode:  65 | score:  -4 | entropy: 0.279
#
# step : 36
# episode:  66 | score:   1 | entropy: 0.268
#
# step : 23
# episode:  67 | score:   0 | entropy: 0.272
#
# step : 22
# episode:  68 | score:  -1 | entropy: 0.278
#
# step : 16
# episode:  69 | score:  -1 | entropy: 0.288
#
# step : 36
# episode:  70 | score:  -5 | entropy: 0.281
#
# step : 19
# episode:  71 | score:  -2 | entropy: 0.278
#
# step : 21
# episode:  72 | score:   0 | entropy: 0.274
#
# step : 54
# episode:  73 | score:  -4 | entropy: 0.276
#
# step : 19
# episode:  74 | score:  -1 | entropy: 0.283
#
# step : 25
# episode:  75 | score:  -2 | entropy: 0.287
#
# step : 21
# episode:  76 | score:   0 | entropy: 0.264
#
# step : 48
# episode:  77 | score:   0 | entropy: 0.270
#
# step : 48
# episode:  78 | score:  -3 | entropy: 0.284
#
# step : 19
# episode:  79 | score:   1 | entropy: 0.250
#
# step : 41
# episode:  80 | score:  -1 | entropy: 0.271
#
# step : 36
# episode:  81 | score:  -3 | entropy: 0.278
#
# step : 21
# episode:  82 | score:   0 | entropy: 0.267
#
# step : 57
# episode:  83 | score:  -7 | entropy: 0.283
#
# step : 17
# episode:  84 | score:  -1 | entropy: 0.272
#
# step : 20
# episode:  85 | score:  -2 | entropy: 0.285
#
# step : 23
# episode:  86 | score:   1 | entropy: 0.269
#
# step : 12
# episode:  87 | score:  -1 | entropy: 0.284
#
# step : 67
# episode:  88 | score:  -3 | entropy: 0.270
#
# step : 21
# episode:  89 | score:   0 | entropy: 0.264
#
# step : 19
# episode:  90 | score:   0 | entropy: 0.274
#
# step : 35
# episode:  91 | score:  -2 | entropy: 0.274
#
# step : 35
# episode:  92 | score:   1 | entropy: 0.270
#
# step : 18
# episode:  93 | score:   1 | entropy: 0.255
#
# step : 22
# episode:  94 | score:   0 | entropy: 0.259
#
# step : 36
# episode:  95 | score:  -1 | entropy: 0.270
#
# step : 20
# episode:  96 | score:   1 | entropy: 0.247
#
# step : 50
# episode:  97 | score:  -2 | entropy: 0.271
#
# step : 23
# episode:  98 | score:   1 | entropy: 0.265
#
# step : 83
# episode:  99 | score:  -6 | entropy: 0.278
#
# step : 53
# episode: 100 | score:   0 | entropy: 0.276
#
# step : 39
# episode: 101 | score:  -1 | entropy: 0.279
#
# step : 26
# episode: 102 | score:   0 | entropy: 0.269
#
# step : 36
# episode: 103 | score:   1 | entropy: 0.247
#
# step : 27
# episode: 104 | score:  -1 | entropy: 0.268
#
# step : 98
# episode: 105 | score:  -4 | entropy: 0.272
#
# step : 110
# episode: 106 | score:   1 | entropy: 0.273
#
# step : 52
# episode: 107 | score:   0 | entropy: 0.264
#
# step : 21
# episode: 108 | score:  -1 | entropy: 0.255
#
# step : 55
# episode: 109 | score:  -1 | entropy: 0.249
#
# step : 14
# episode: 110 | score:   1 | entropy: 0.264
#
# step : 17
# episode: 111 | score:   1 | entropy: 0.251
#
# step : 36
# episode: 112 | score:   0 | entropy: 0.249
#
# step : 21
# episode: 113 | score:  -1 | entropy: 0.249
#
# step : 16
# episode: 114 | score:   1 | entropy: 0.255
#
# step : 21
# episode: 115 | score:   0 | entropy: 0.258
#
# step : 20
# episode: 116 | score:   1 | entropy: 0.241
#
# step : 51
# episode: 117 | score:   1 | entropy: 0.254
#
# step : 13
# episode: 118 | score:   1 | entropy: 0.252
#
# step : 18
# episode: 119 | score:  -1 | entropy: 0.266
#
# step : 59
# episode: 120 | score:  -1 | entropy: 0.262
#
# step : 33
# episode: 121 | score:  -2 | entropy: 0.261
#
# step : 30
# episode: 122 | score:  -2 | entropy: 0.269
#
# step : 23
# episode: 123 | score:  -1 | entropy: 0.262
#
# step : 20
# episode: 124 | score:   0 | entropy: 0.238
#
# step : 26
# episode: 125 | score:   0 | entropy: 0.271
#
# step : 36
# episode: 126 | score:   0 | entropy: 0.255
#
# step : 50
# episode: 127 | score:   0 | entropy: 0.262
#
# step : 31
# episode: 128 | score:   1 | entropy: 0.259
#
# step : 36
# episode: 129 | score:  -2 | entropy: 0.257
#
# step : 18
# episode: 130 | score:   1 | entropy: 0.234
#
# step : 75
# episode: 131 | score:  -1 | entropy: 0.258
#
# step : 35
# episode: 132 | score:   1 | entropy: 0.247
#
# step : 37
# episode: 133 | score:  -4 | entropy: 0.245
#
# step : 31
# episode: 134 | score:  -1 | entropy: 0.262
#
# step : 51
# episode: 135 | score:  -2 | entropy: 0.256
#
# step : 17
# episode: 136 | score:   1 | entropy: 0.250
#
# step : 67
# episode: 137 | score:   0 | entropy: 0.261
#
# step : 49
# episode: 138 | score:  -1 | entropy: 0.257
#
# step : 20
# episode: 139 | score:   1 | entropy: 0.242
#
# step : 38
# episode: 140 | score:  -6 | entropy: 0.260
#
# step : 45
# episode: 141 | score:   0 | entropy: 0.242
#
# step : 35
# episode: 142 | score:   1 | entropy: 0.254
#
# step : 21
# episode: 143 | score:   0 | entropy: 0.236
#
# step : 21
# episode: 144 | score:   0 | entropy: 0.244
#
# step : 23
# episode: 145 | score:   0 | entropy: 0.239
#
# step : 36
# episode: 146 | score:   1 | entropy: 0.240
#
# step : 47
# episode: 147 | score:  -2 | entropy: 0.245
#
# step : 14
# episode: 148 | score:   0 | entropy: 0.274
#
# step : 17
# episode: 149 | score:  -1 | entropy: 0.252
#
# step : 15
# episode: 150 | score:   1 | entropy: 0.253
#
# step : 18
# episode: 151 | score:   1 | entropy: 0.231
# step : 29
# episode: 152 | score:  -3 | entropy: 0.270
#
# step : 16
# episode: 153 | score:   1 | entropy: 0.224
#
# step : 15
# episode: 154 | score:  -1 | entropy: 0.262
#
# step : 32
# episode: 155 | score:   0 | entropy: 0.260
#
# step : 31
# episode: 156 | score:  -1 | entropy: 0.258
#
# step : 20
# episode: 157 | score:   0 | entropy: 0.228
#
# step : 35
# episode: 158 | score:   0 | entropy: 0.241
#
# step : 25
# episode: 159 | score:  -1 | entropy: 0.235
#
# step : 18
# episode: 160 | score:   1 | entropy: 0.233
#
# step : 19
# episode: 161 | score:   1 | entropy: 0.233
#
# step : 20
# episode: 162 | score:   1 | entropy: 0.240
#
# step : 26
# episode: 163 | score:  -1 | entropy: 0.231
#
# step : 21
# episode: 164 | score:   0 | entropy: 0.242
#
# step : 18
# episode: 165 | score:   1 | entropy: 0.227
#
# step : 19
# episode: 166 | score:   1 | entropy: 0.234
#
# step : 18
# episode: 167 | score:   1 | entropy: 0.234
#
# step : 20
# episode: 168 | score:   1 | entropy: 0.241
#
# step : 26
# episode: 169 | score:  -2 | entropy: 0.254
#
# step : 21
# episode: 170 | score:   0 | entropy: 0.226
#
# step : 22
# episode: 171 | score:   1 | entropy: 0.228
#
# step : 17
# episode: 172 | score:   1 | entropy: 0.235
#
# step : 17
# episode: 173 | score:   0 | entropy: 0.234
#
# step : 51
# episode: 174 | score:   1 | entropy: 0.241
#
# step : 62
# episode: 175 | score:   1 | entropy: 0.256
#
# step : 20
# episode: 176 | score:   1 | entropy: 0.235
#
# step : 22
# episode: 177 | score:   0 | entropy: 0.237
#
# step : 22
# episode: 178 | score:  -1 | entropy: 0.248
#
# step : 30
# episode: 179 | score:   1 | entropy: 0.227
#
# step : 36
# episode: 180 | score:   1 | entropy: 0.227
#
# step : 19
# episode: 181 | score:   1 | entropy: 0.221
#
# step : 17
# episode: 182 | score:   1 | entropy: 0.226
#
# step : 20
# episode: 183 | score:   1 | entropy: 0.245
#
# step : 18
# episode: 184 | score:   1 | entropy: 0.230
#
# step : 50
# episode: 185 | score:   1 | entropy: 0.246
#
# step : 17
# episode: 186 | score:   1 | entropy: 0.228
#
# step : 42
# episode: 187 | score:  -1 | entropy: 0.259
#
# step : 25
# episode: 188 | score:  -2 | entropy: 0.245
#
# step : 34
# episode: 189 | score:   1 | entropy: 0.241
#
# step : 22
# episode: 190 | score:   0 | entropy: 0.237
#
# step : 17
# episode: 191 | score:   1 | entropy: 0.226
#
# step : 18
# episode: 192 | score:   1 | entropy: 0.223
#
# step : 145
# episode: 193 | score:   0 | entropy: 0.250
#
# step : 35
# episode: 194 | score:   1 | entropy: 0.233
#
# step : 33
# episode: 195 | score:   1 | entropy: 0.225
#
# step : 52
# episode: 196 | score:  -1 | entropy: 0.238
#
# step : 30
# episode: 197 | score:   0 | entropy: 0.261
#
# step : 36
# episode: 198 | score:  -2 | entropy: 0.246
#
# step : 21
# episode: 199 | score:   0 | entropy: 0.224
#
# step : 32
# episode: 200 | score:   1 | entropy: 0.237
#
# step : 20
# episode: 201 | score:   0 | entropy: 0.222
#
# step : 19
# episode: 202 | score:   1 | entropy: 0.224
#
# step : 50
# episode: 203 | score:   1 | entropy: 0.248
#
# step : 37
# episode: 204 | score:   0 | entropy: 0.223
#
# step : 17
# episode: 205 | score:   1 | entropy: 0.216
#
# step : 20
# episode: 206 | score:   1 | entropy: 0.206
#
# step : 28
# episode: 207 | score:  -1 | entropy: 0.233
#
# step : 18
# episode: 208 | score:   1 | entropy: 0.226
#
# step : 28
# episode: 209 | score:   0 | entropy: 0.206
#
# step : 19
# episode: 210 | score:   1 | entropy: 0.215
#
# step : 22
# episode: 211 | score:   1 | entropy: 0.199
#
# step : 20
# episode: 212 | score:  -1 | entropy: 0.190
#
# step : 52
# episode: 213 | score:   0 | entropy: 0.229
#
# step : 19
# episode: 214 | score:   1 | entropy: 0.209
#
# step : 18
# episode: 215 | score:   1 | entropy: 0.206
#
# step : 21
# episode: 216 | score:   0 | entropy: 0.208
#
# step : 40
# episode: 217 | score:  -1 | entropy: 0.244
#
# step : 48
# episode: 218 | score:   1 | entropy: 0.237
#
# step : 48
# episode: 219 | score:  -5 | entropy: 0.242
#
# step : 33
# episode: 220 | score:   1 | entropy: 0.217
#
# step : 23
# episode: 221 | score:   0 | entropy: 0.238
#
# step : 33
# episode: 222 | score:   1 | entropy: 0.220
#
# step : 40
# episode: 223 | score:   0 | entropy: 0.238
#
# step : 18
# episode: 224 | score:   1 | entropy: 0.223
#
# step : 24
# episode: 225 | score:   1 | entropy: 0.200
#
# step : 43
# episode: 226 | score:  -3 | entropy: 0.231
#
# step : 23
# episode: 227 | score:   0 | entropy: 0.207
#
# step : 42
# episode: 228 | score:  -5 | entropy: 0.243
#
# step : 19
# episode: 229 | score:   1 | entropy: 0.202
#
# step : 19
# episode: 230 | score:   1 | entropy: 0.196
#
# step : 36
# episode: 231 | score:  -2 | entropy: 0.232
#
# step : 18
# episode: 232 | score:   1 | entropy: 0.224
#
# step : 17
# episode: 233 | score:   1 | entropy: 0.224
#
# step : 21
# episode: 234 | score:   0 | entropy: 0.214
#
# step : 38
# episode: 235 | score:   0 | entropy: 0.228
#
# step : 23
# episode: 236 | score:   1 | entropy: 0.230
#
# step : 17
# episode: 237 | score:   1 | entropy: 0.205
#
# step : 18
# episode: 238 | score:   1 | entropy: 0.219
#
# step : 18
# episode: 239 | score:   1 | entropy: 0.201
#
# step : 18
# episode: 240 | score:   1 | entropy: 0.190
#
# step : 37
# episode: 241 | score:  -3 | entropy: 0.223
#
# step : 17
# episode: 242 | score:   0 | entropy: 0.188
#
# step : 12
# episode: 243 | score:  -1 | entropy: 0.250
#
# step : 19
# episode: 244 | score:   1 | entropy: 0.204
#
# step : 17
# episode: 245 | score:   1 | entropy: 0.203
#
# step : 16
# episode: 246 | score:   1 | entropy: 0.209
#
# step : 18
# episode: 247 | score:  -1 | entropy: 0.227
#
# step : 19
# episode: 248 | score:   1 | entropy: 0.213
#
# step : 18
# episode: 249 | score:   1 | entropy: 0.205
#
# step : 17
# episode: 250 | score:   1 | entropy: 0.209
#
# step : 18
# episode: 251 | score:   1 | entropy: 0.224
#
# step : 20
# episode: 252 | score:   1 | entropy: 0.201
#
# step : 69
# episode: 253 | score:   0 | entropy: 0.220
#
# step : 37
# episode: 254 | score:   0 | entropy: 0.224
#
# step : 19
# episode: 255 | score:   1 | entropy: 0.204
#
# step : 21
# episode: 256 | score:  -1 | entropy: 0.207
#
# step : 21
# episode: 257 | score:   0 | entropy: 0.221
#
# step : 18
# episode: 258 | score:   1 | entropy: 0.194
#
# step : 39
# episode: 259 | score:   0 | entropy: 0.226
#
# step : 20
# episode: 260 | score:   1 | entropy: 0.223
#
# step : 16
# episode: 261 | score:   1 | entropy: 0.232
#
# step : 36
# episode: 262 | score:   1 | entropy: 0.218
#
# step : 21
# episode: 263 | score:   0 | entropy: 0.198
#
# step : 17
# episode: 264 | score:   1 | entropy: 0.205
#
# step : 18
# episode: 265 | score:   1 | entropy: 0.213
#
# step : 20
# episode: 266 | score:   1 | entropy: 0.202
#
# step : 20
# episode: 267 | score:   1 | entropy: 0.198
#
# step : 20
# episode: 268 | score:   1 | entropy: 0.211
#
# step : 20
# episode: 269 | score:   1 | entropy: 0.191
#
# step : 18
# episode: 270 | score:   1 | entropy: 0.211
#
# step : 37
# episode: 271 | score:   0 | entropy: 0.228
#
# step : 18
# episode: 272 | score:   1 | entropy: 0.207
#
# step : 20
# episode: 273 | score:   0 | entropy: 0.201
#
# step : 18
# episode: 274 | score:   1 | entropy: 0.209
#
# step : 19
# episode: 275 | score:   1 | entropy: 0.197
#
# step : 17
# episode: 276 | score:   1 | entropy: 0.198
#
# step : 17
# episode: 277 | score:   1 | entropy: 0.201
#
# step : 36
# episode: 278 | score:   1 | entropy: 0.233
#
# step : 19
# episode: 279 | score:   1 | entropy: 0.215
#
# step : 17
# episode: 280 | score:   1 | entropy: 0.212
#
# step : 37
# episode: 281 | score:   0 | entropy: 0.209
#
# step : 21
# episode: 282 | score:   0 | entropy: 0.199
#
# step : 27
# episode: 283 | score:  -1 | entropy: 0.227
#
# step : 56
# episode: 284 | score:   0 | entropy: 0.223
#
# step : 33
# episode: 285 | score:   1 | entropy: 0.223
#
# step : 31
# episode: 286 | score:  -1 | entropy: 0.233
#
# step : 20
# episode: 287 | score:   0 | entropy: 0.213
#
# step : 17
# episode: 288 | score:   1 | entropy: 0.210
#
# step : 19
# episode: 289 | score:   1 | entropy: 0.198
#
# step : 34
# episode: 290 | score:   1 | entropy: 0.208
#
# step : 21
# episode: 291 | score:   0 | entropy: 0.214
#
# step : 39
# episode: 292 | score:  -7 | entropy: 0.244
#
# step : 17
# episode: 293 | score:   0 | entropy: 0.216
#
# step : 24
# episode: 294 | score:   0 | entropy: 0.231
#
# step : 17
# episode: 295 | score:   1 | entropy: 0.220
#
# step : 16
# episode: 296 | score:   1 | entropy: 0.199
#
# step : 52
# episode: 297 | score:   0 | entropy: 0.217
#
# step : 49
# episode: 298 | score:   1 | entropy: 0.211
#
# step : 20
# episode: 299 | score:   1 | entropy: 0.197
#
# step : 65
# episode: 300 | score:   0 | entropy: 0.229
#
# step : 18
# episode: 301 | score:   1 | entropy: 0.212
#
# step : 20
# episode: 302 | score:   0 | entropy: 0.222
#
# step : 50
# episode: 303 | score:   1 | entropy: 0.219
# step : 21
# episode: 304 | score:   1 | entropy: 0.219
#
# step : 52
# episode: 305 | score:   1 | entropy: 0.215
#
# step : 17
# episode: 306 | score:   1 | entropy: 0.218
#
# step : 38
# episode: 307 | score:  -1 | entropy: 0.225
#
# step : 25
# episode: 308 | score:   0 | entropy: 0.233
#
# step : 17
# episode: 309 | score:   1 | entropy: 0.201
#
# step : 50
# episode: 310 | score:   1 | entropy: 0.224
#
# step : 16
# episode: 311 | score:   1 | entropy: 0.213
#
# step : 32
# episode: 312 | score:   1 | entropy: 0.216
#
# step : 34
# episode: 313 | score:   1 | entropy: 0.222
#
# step : 33
# episode: 314 | score:   1 | entropy: 0.203
#
# step : 54
# episode: 315 | score:   0 | entropy: 0.214
#
# step : 20
# episode: 316 | score:   1 | entropy: 0.197
#
# step : 19
# episode: 317 | score:   1 | entropy: 0.209
#
# step : 16
# episode: 318 | score:   1 | entropy: 0.203
#
# step : 67
# episode: 319 | score:   1 | entropy: 0.226
#
# step : 18
# episode: 320 | score:   1 | entropy: 0.223
#
# step : 53
# episode: 321 | score:   0 | entropy: 0.207
#
# step : 17
# episode: 322 | score:   1 | entropy: 0.198
#
# step : 19
# episode: 323 | score:   1 | entropy: 0.206
#
# step : 34
# episode: 324 | score:   1 | entropy: 0.203
#
# step : 47
# episode: 325 | score:  -2 | entropy: 0.219
#
# step : 18
# episode: 326 | score:   1 | entropy: 0.207
#
# step : 52
# episode: 327 | score:   1 | entropy: 0.214
#
# step : 18
# episode: 328 | score:   1 | entropy: 0.207
#
# step : 20
# episode: 329 | score:   1 | entropy: 0.200
#
# step : 20
# episode: 330 | score:   1 | entropy: 0.197
#
# step : 23
# episode: 331 | score:   0 | entropy: 0.199
#
# step : 34
# episode: 332 | score:   0 | entropy: 0.212
#
# step : 17
# episode: 333 | score:   1 | entropy: 0.204
#
# step : 16
# episode: 334 | score:   1 | entropy: 0.208
#
# step : 36
# episode: 335 | score:   1 | entropy: 0.212
#
# step : 21
# episode: 336 | score:   0 | entropy: 0.204
#
# step : 51
# episode: 337 | score:   1 | entropy: 0.221
#
# step : 19
# episode: 338 | score:   1 | entropy: 0.197
#
# step : 22
# episode: 339 | score:   0 | entropy: 0.219
#
# step : 21
# episode: 340 | score:   0 | entropy: 0.206
#
# step : 21
# episode: 341 | score:   0 | entropy: 0.217
#
# step : 36
# episode: 342 | score:   1 | entropy: 0.210
#
# step : 19
# episode: 343 | score:   1 | entropy: 0.203
#
# step : 34
# episode: 344 | score:  -2 | entropy: 0.227
#
# step : 34
# episode: 345 | score:   1 | entropy: 0.216
#
# step : 22
# episode: 346 | score:   0 | entropy: 0.206
#
# step : 19
# episode: 347 | score:   1 | entropy: 0.217
#
# step : 32
# episode: 348 | score:   1 | entropy: 0.216
#
# step : 21
# episode: 349 | score:   0 | entropy: 0.208
#
# step : 18
# episode: 350 | score:   1 | entropy: 0.205
#
# step : 20
# episode: 351 | score:   1 | entropy: 0.191
#
# step : 21
# episode: 352 | score:   0 | entropy: 0.209
#
# step : 15
# episode: 353 | score:   1 | entropy: 0.224
#
# step : 17
# episode: 354 | score:   1 | entropy: 0.205
#
# step : 19
# episode: 355 | score:   1 | entropy: 0.202
#
# step : 18
# episode: 356 | score:   1 | entropy: 0.206
#
# step : 21
# episode: 357 | score:   0 | entropy: 0.203
#
# step : 33
# episode: 358 | score:   1 | entropy: 0.217
#
# step : 18
# episode: 359 | score:   1 | entropy: 0.199
#
# step : 37
# episode: 360 | score:   0 | entropy: 0.221
#
# step : 22
# episode: 361 | score:   1 | entropy: 0.188
#
# step : 17
# episode: 362 | score:   1 | entropy: 0.193
#
# step : 34
# episode: 363 | score:   1 | entropy: 0.220
#
# step : 19
# episode: 364 | score:   1 | entropy: 0.212
#
# step : 20
# episode: 365 | score:   0 | entropy: 0.202
#
# step : 51
# episode: 366 | score:   1 | entropy: 0.207
#
# step : 35
# episode: 367 | score:   1 | entropy: 0.227
#
# step : 19
# episode: 368 | score:   1 | entropy: 0.190
#
# step : 34
# episode: 369 | score:   1 | entropy: 0.210
#
# step : 23
# episode: 370 | score:   0 | entropy: 0.227
#
# step : 48
# episode: 371 | score:   1 | entropy: 0.210
#
# step : 19
# episode: 372 | score:   1 | entropy: 0.191
#
# step : 22
# episode: 373 | score:   0 | entropy: 0.195
#
# step : 37
# episode: 374 | score:   0 | entropy: 0.206
#
# step : 17
# episode: 375 | score:   1 | entropy: 0.201
#
# step : 21
# episode: 376 | score:   0 | entropy: 0.202
#
# step : 21
# episode: 377 | score:   0 | entropy: 0.222
#
# step : 34
# episode: 378 | score:   1 | entropy: 0.208
#
# step : 34
# episode: 379 | score:   1 | entropy: 0.223
#
# step : 17
# episode: 380 | score:   1 | entropy: 0.195
#
# step : 23
# episode: 381 | score:  -1 | entropy: 0.182
#
# step : 71
# episode: 382 | score:  -3 | entropy: 0.208
#
# step : 95
# episode: 383 | score:   1 | entropy: 0.212
#
# step : 64
# episode: 384 | score:   1 | entropy: 0.222
#
# step : 22
# episode: 385 | score:   0 | entropy: 0.198
#
# step : 17
# episode: 386 | score:   1 | entropy: 0.192
#
# step : 16
# episode: 387 | score:   1 | entropy: 0.189
#
# step : 68
# episode: 388 | score:   0 | entropy: 0.209
#
# step : 18
# episode: 389 | score:   1 | entropy: 0.195
#
# step : 19
# episode: 390 | score:   1 | entropy: 0.181
#
# step : 51
# episode: 391 | score:   1 | entropy: 0.208
#
# step : 66
# episode: 392 | score:   1 | entropy: 0.207
#
# step : 20
# episode: 393 | score:   0 | entropy: 0.207
#
# step : 18
# episode: 394 | score:   1 | entropy: 0.194
#
# step : 21
# episode: 395 | score:   0 | entropy: 0.192
#
# step : 18
# episode: 396 | score:   1 | entropy: 0.198
#
# step : 64
# episode: 397 | score:   1 | entropy: 0.225
#
# step : 17
# episode: 398 | score:   1 | entropy: 0.193
#
# step : 34
# episode: 399 | score:   1 | entropy: 0.207
#
# step : 23
# episode: 400 | score:   0 | entropy: 0.219
#
# step : 21
# episode: 401 | score:   0 | entropy: 0.204
#
# step : 34
# episode: 402 | score:   1 | entropy: 0.200
#
# step : 19
# episode: 403 | score:   1 | entropy: 0.187
#
# step : 20
# episode: 404 | score:   1 | entropy: 0.209
#
# step : 18
# episode: 405 | score:   1 | entropy: 0.188
#
# step : 39
# episode: 406 | score:   1 | entropy: 0.226
#
# step : 38
# episode: 407 | score:   1 | entropy: 0.211
#
# step : 65
# episode: 408 | score:  -1 | entropy: 0.235
#
# step : 39
# episode: 409 | score:   1 | entropy: 0.212
#
# step : 17
# episode: 410 | score:   1 | entropy: 0.182
#
# step : 19
# episode: 411 | score:   1 | entropy: 0.201
#
# step : 160
# episode: 412 | score: -11 | entropy: 0.220
#
# step : 19
# episode: 413 | score:   1 | entropy: 0.186
#
# step : 50
# episode: 414 | score:   1 | entropy: 0.211
#
# step : 115
# episode: 415 | score:   1 | entropy: 0.209
#
# step : 181
# episode: 416 | score:   1 | entropy: 0.210
#
# step : 194
# episode: 417 | score:   0 | entropy: 0.212
#
# step : 20
# episode: 418 | score:   1 | entropy: 0.188
#
# step : 67
# episode: 419 | score:   1 | entropy: 0.209
#
# step : 50
# episode: 420 | score:   1 | entropy: 0.208
#
# step : 35
# episode: 421 | score:   1 | entropy: 0.222
#
# step : 17
# episode: 422 | score:   1 | entropy: 0.185
#
# step : 79
# episode: 423 | score:   1 | entropy: 0.213
#
# step : 19
# episode: 424 | score:   1 | entropy: 0.186
#
# step : 66
# episode: 425 | score:   1 | entropy: 0.206
#
# step : 19
# episode: 426 | score:   0 | entropy: 0.188
#
# step : 244
# episode: 427 | score:  -3 | entropy: 0.210
#
# step : 105
# episode: 428 | score:  -2 | entropy: 0.211
#
# step : 85
# episode: 429 | score:   0 | entropy: 0.217
#
# step : 52
# episode: 430 | score:   1 | entropy: 0.200
#
# step : 85
# episode: 431 | score:  -1 | entropy: 0.214
#
# step : 18
# episode: 432 | score:   1 | entropy: 0.182
#
# step : 20
# episode: 433 | score:   0 | entropy: 0.186
#
# step : 97
# episode: 434 | score:   1 | entropy: 0.216
#
# step : 38
# episode: 435 | score:   0 | entropy: 0.209
#
# step : 37
# episode: 436 | score:   0 | entropy: 0.202
#
# step : 81
# episode: 437 | score:   1 | entropy: 0.210
#
# step : 36
# episode: 438 | score:   1 | entropy: 0.198
#
# step : 163
# episode: 439 | score:  -1 | entropy: 0.217
#
# step : 51
# episode: 440 | score:   0 | entropy: 0.204
#
# step : 146
# episode: 441 | score:   1 | entropy: 0.208
#
# step : 68
# episode: 442 | score:   1 | entropy: 0.219
#
# step : 21
# episode: 443 | score:   0 | entropy: 0.199
#
# step : 17
# episode: 444 | score:   1 | entropy: 0.182
#
# step : 82
# episode: 445 | score:   1 | entropy: 0.206
#
# step : 16
# episode: 446 | score:   1 | entropy: 0.195
#
# step : 18
# episode: 447 | score:   1 | entropy: 0.198
#
# step : 38
# episode: 448 | score:   0 | entropy: 0.190
#
# step : 49
# episode: 449 | score:   1 | entropy: 0.193
#
# step : 117
# episode: 450 | score:   0 | entropy: 0.196
#
# step : 20
# episode: 451 | score:   1 | entropy: 0.188
#
# step : 21
# episode: 452 | score:   0 | entropy: 0.168
#
# step : 56
# episode: 453 | score:  -4 | entropy: 0.218
#
# step : 86
# episode: 454 | score:   1 | entropy: 0.203
#
# step : 118
# episode: 455 | score:   1 | entropy: 0.188
# step : 16
# episode: 456 | score:   1 | entropy: 0.172
#
# step : 97
# episode: 457 | score:  -1 | entropy: 0.186
#
# step : 133
# episode: 458 | score:   0 | entropy: 0.164
#
# step : 68
# episode: 459 | score:   0 | entropy: 0.156
#
# step : 305
# episode: 460 | score:  -5 | entropy: 0.163
#
# step : 67
# episode: 461 | score:   1 | entropy: 0.156
#
# step : 20
# episode: 462 | score:   0 | entropy: 0.166
#
# step : 232
# episode: 463 | score:  -5 | entropy: 0.167
#
# step : 99
# episode: 464 | score:   1 | entropy: 0.155
#
# step : 244
# episode: 465 | score:   1 | entropy: 0.147
#
# step : 228
# episode: 466 | score:   1 | entropy: 0.139
#
# step : 1187
# episode: 467 | score:  -2 | entropy: 0.142
#
# step : 758
# episode: 468 | score:   1 | entropy: 0.124
#
# step : 1236
# episode: 469 | score:  -7 | entropy: 0.116
#
# step : 1762
# episode: 470 | score:   1 | entropy: 0.098
#
# step : 6580
# episode: 471 | score:   0 | entropy: 0.086
#
# step : 6850
# episode: 472 | score:   1 | entropy: 0.077
#
# step : 14418
# episode: 473 | score:  -9 | entropy: 0.070
#
# step : 7507
# episode: 474 | score:   1 | entropy: 0.080
#
# step : 7780
# episode: 475 | score: -11 | entropy: 0.091
#
# step : 1842
# episode: 476 | score:   1 | entropy: 0.081
#
# step : 1445
# episode: 477 | score:   0 | entropy: 0.073
